# %% [markdown]
# <a href="https://colab.research.google.com/github/jeniferGoncalvesDaSilvaDev/Estatistica-python/blob/main/data_viz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sb
import matplotlib.pyplot as plt

# %%
data = sb.load_dataset("tips")
print(data.head(6))
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4

# %%
print(data.describe())
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
def hist():
    sb.histplot(data["total_bill"], kde = True).set_title("Histogram of Total")
    #sb.histplot(data["tip"],kde=True).set_title("Histogram of tips")

print(hist())
# Out:
# None

# %%
def hist_tip():
   return sb.histplot(data["tip"],kde=True).set_title("Histogram of tips")
print(hist_tip())
# Out:
# Text(0.5, 1.0, 'Histogram of tips')

# %%
sb.scatterplot(x="total_bill", y="tip", hue="sex",data=data)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>
